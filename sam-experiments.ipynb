# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)
    polygons = []
    color = []
    for ann in sorted_anns:
        m = ann['segmentation']
        img = np.ones((m.shape[0], m.shape[1], 3))
        color_mask = np.random.random((1, 3)).tolist()[0]
        for i in range(3):
            img[:,:,i] = color_mask[i]
        ax.imshow(np.dstack((img, m*0.35)))

# %%
image = cv2.imread('images/surf_sagres.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

device = "cuda"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
# sam.to(device=device)

mask_generator = SamAutomaticMaskGenerator(sam)

# %%
masks = mask_generator.generate(image)

# %%
plt.figure(figsize=(10,10))
plt.imshow(image)
show_anns(masks)
plt.axis('off')
plt.show()

# %%
masks
# Out:
# [{'segmentation': array([[False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 655421,
#   'bbox': [3, 0, 1194, 645],
#   'predicted_iou': 1.0220392942428589,
#   'point_coords': [[131.25, 375.0]],
#   'stability_score': 0.9925333261489868,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 135562,
#   'bbox': [0, 599, 310, 833],
#   'predicted_iou': 1.018805980682373,
#   'point_coords': [[93.75, 1025.0]],
#   'stability_score': 0.9728177785873413,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          [False, False, False, ...,  True, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 656275,
#   'bbox': [3, 0, 1194, 957],
#   'predicted_iou': 1.016567349433899,
#   'point_coords': [[18.75, 425.0]],
#   'stability_score': 0.9928456544876099,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 199230,
#   'bbox': [0, 882, 872, 440],
#   'predicted_iou': 1.0149697065353394,
#   'point_coords': [[356.25, 1175.0]],
#   'stability_score': 0.980010449886322,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 476176,
#   'bbox': [3, 652, 1195, 947],
#   'predicted_iou': 1.012712836265564,
#   'point_coords': [[168.75, 1575.0]],
#   'stability_score': 0.9775782227516174,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 48903,
#   'bbox': [538, 644, 231, 250],
#   'predicted_iou': 1.0112823247909546,
#   'point_coords': [[618.75, 725.0]],
#   'stability_score': 0.9909836649894714,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 23403,
#   'bbox': [546, 294, 212, 278],
#   'predicted_iou': 1.0067139863967896,
#   'point_coords': [[581.25, 375.0]],
#   'stability_score': 0.9914486408233643,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 23393,
#   'bbox': [545, 294, 205, 153],
#   'predicted_iou': 1.0066370964050293,
#   'point_coords': [[581.25, 425.0]],
#   'stability_score': 0.9919533133506775,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 87757,
#   'bbox': [0, 600, 311, 394],
#   'predicted_iou': 1.0034674406051636,
#   'point_coords': [[281.25, 925.0]],
#   'stability_score': 0.9599619507789612,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 478609,
#   'bbox': [0, 15, 1198, 1584],
#   'predicted_iou': 1.000622272491455,
#   'point_coords': [[656.25, 1375.0]],
#   'stability_score': 0.968176543712616,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 44646,
#   'bbox': [771, 661, 282, 229],
#   'predicted_iou': 1.0001189708709717,
#   'point_coords': [[806.25, 825.0]],
#   'stability_score': 0.9809994697570801,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 102373,
#   'bbox': [719, 890, 310, 571],
#   'predicted_iou': 0.9971834421157837,
#   'point_coords': [[993.75, 1275.0]],
#   'stability_score': 0.9862256050109863,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5846,
#   'bbox': [577, 925, 81, 112],
#   'predicted_iou': 0.9965764284133911,
#   'point_coords': [[618.75, 975.0]],
#   'stability_score': 0.9887659549713135,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6375,
#   'bbox': [792, 595, 90, 100],
#   'predicted_iou': 0.9958692193031311,
#   'point_coords': [[843.75, 675.0]],
#   'stability_score': 0.9771004319190979,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 307766,
#   'bbox': [0, 1169, 1196, 430],
#   'predicted_iou': 0.9939563274383545,
#   'point_coords': [[93.75, 1325.0]],
#   'stability_score': 0.9546514749526978,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6411,
#   'bbox': [792, 595, 91, 196],
#   'predicted_iou': 0.9934958815574646,
#   'point_coords': [[843.75, 625.0]],
#   'stability_score': 0.9696969985961914,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 45987,
#   'bbox': [87, 977, 172, 456],
#   'predicted_iou': 0.9906250238418579,
#   'point_coords': [[131.25, 1075.0]],
#   'stability_score': 0.959878146648407,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4620,
#   'bbox': [0, 964, 51, 109],
#   'predicted_iou': 0.9891408085823059,
#   'point_coords': [[18.75, 1025.0]],
#   'stability_score': 0.9892218112945557,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5411,
#   'bbox': [151, 445, 110, 92],
#   'predicted_iou': 0.9888884425163269,
#   'point_coords': [[243.75, 475.0]],
#   'stability_score': 0.9836786985397339,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 10333,
#   'bbox': [151, 496, 106, 128],
#   'predicted_iou': 0.9888280034065247,
#   'point_coords': [[168.75, 525.0]],
#   'stability_score': 0.9854000806808472,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8178,
#   'bbox': [611, 535, 89, 118],
#   'predicted_iou': 0.9886595010757446,
#   'point_coords': [[656.25, 575.0]],
#   'stability_score': 0.9834851026535034,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3392,
#   'bbox': [509, 1266, 67, 89],
#   'predicted_iou': 0.9857556819915771,
#   'point_coords': [[543.75, 1325.0]],
#   'stability_score': 0.9795799255371094,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3720,
#   'bbox': [556, 469, 88, 74],
#   'predicted_iou': 0.9837217330932617,
#   'point_coords': [[581.25, 525.0]],
#   'stability_score': 0.9818859696388245,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4521,
#   'bbox': [771, 566, 108, 93],
#   'predicted_iou': 0.9785903096199036,
#   'point_coords': [[843.75, 575.0]],
#   'stability_score': 0.9800700545310974,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 46212,
#   'bbox': [83, 776, 175, 658],
#   'predicted_iou': 0.9777430295944214,
#   'point_coords': [[206.25, 1375.0]],
#   'stability_score': 0.9617765545845032,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2106,
#   'bbox': [546, 1204, 45, 64],
#   'predicted_iou': 0.9764184355735779,
#   'point_coords': [[581.25, 1225.0]],
#   'stability_score': 0.9835603833198547,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 72028,
#   'bbox': [511, 508, 258, 846],
#   'predicted_iou': 0.9756420850753784,
#   'point_coords': [[731.25, 825.0]],
#   'stability_score': 0.9749725461006165,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 16780,
#   'bbox': [848, 892, 129, 194],
#   'predicted_iou': 0.9745570421218872,
#   'point_coords': [[956.25, 1025.0]],
#   'stability_score': 0.968795895576477,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2606,
#   'bbox': [610, 506, 88, 66],
#   'predicted_iou': 0.9731131792068481,
#   'point_coords': [[656.25, 525.0]],
#   'stability_score': 0.9802506566047668,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 23757,
#   'bbox': [527, 438, 233, 139],
#   'predicted_iou': 0.9719146490097046,
#   'point_coords': [[543.75, 525.0]],
#   'stability_score': 0.9756412506103516,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 66955,
#   'bbox': [772, 566, 282, 829],
#   'predicted_iou': 0.9696649312973022,
#   'point_coords': [[1031.25, 775.0]],
#   'stability_score': 0.9705765247344971,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 368498,
#   'bbox': [4, 0, 1192, 354],
#   'predicted_iou': 0.9674637913703918,
#   'point_coords': [[1068.75, 25.0]],
#   'stability_score': 0.9582331776618958,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8869,
#   'bbox': [247, 1142, 119, 144],
#   'predicted_iou': 0.964724600315094,
#   'point_coords': [[318.75, 1175.0]],
#   'stability_score': 0.9691110849380493,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8766,
#   'bbox': [771, 1437, 101, 162],
#   'predicted_iou': 0.9627828001976013,
#   'point_coords': [[843.75, 1525.0]],
#   'stability_score': 0.9767625331878662,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 174189,
#   'bbox': [222, 881, 650, 410],
#   'predicted_iou': 0.9625365138053894,
#   'point_coords': [[506.25, 925.0]],
#   'stability_score': 0.9584085941314697,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 21846,
#   'bbox': [0, 305, 573, 54],
#   'predicted_iou': 0.9600878357887268,
#   'point_coords': [[431.25, 325.0]],
#   'stability_score': 0.9570310711860657,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 59302,
#   'bbox': [538, 508, 231, 386],
#   'predicted_iou': 0.960052490234375,
#   'point_coords': [[618.75, 775.0]],
#   'stability_score': 0.9845247864723206,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2860,
#   'bbox': [487, 1548, 71, 51],
#   'predicted_iou': 0.9592816829681396,
#   'point_coords': [[506.25, 1575.0]],
#   'stability_score': 0.9775319695472717,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 7291,
#   'bbox': [580, 1183, 82, 106],
#   'predicted_iou': 0.9583705067634583,
#   'point_coords': [[618.75, 1275.0]],
#   'stability_score': 0.9810961484909058,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6831,
#   'bbox': [546, 1153, 173, 120],
#   'predicted_iou': 0.9562845230102539,
#   'point_coords': [[693.75, 1225.0]],
#   'stability_score': 0.9651848673820496,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4025,
#   'bbox': [863, 476, 168, 29],
#   'predicted_iou': 0.9560719728469849,
#   'point_coords': [[918.75, 475.0]],
#   'stability_score': 0.9610231518745422,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3444,
#   'bbox': [309, 1532, 68, 67],
#   'predicted_iou': 0.9557642936706543,
#   'point_coords': [[356.25, 1575.0]],
#   'stability_score': 0.9730813503265381,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3444,
#   'bbox': [992, 1295, 54, 101],
#   'predicted_iou': 0.9552793502807617,
#   'point_coords': [[993.75, 1325.0]],
#   'stability_score': 0.9793162941932678,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2996,
#   'bbox': [663, 1272, 54, 78],
#   'predicted_iou': 0.9548577666282654,
#   'point_coords': [[693.75, 1325.0]],
#   'stability_score': 0.9710240364074707,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 798,
#   'bbox': [280, 956, 35, 31],
#   'predicted_iou': 0.95359867811203,
#   'point_coords': [[281.25, 975.0]],
#   'stability_score': 0.977667510509491,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4575,
#   'bbox': [962, 624, 237, 27],
#   'predicted_iou': 0.9525309801101685,
#   'point_coords': [[993.75, 625.0]],
#   'stability_score': 0.9629550576210022,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 15214,
#   'bbox': [151, 446, 110, 177],
#   'predicted_iou': 0.9520115852355957,
#   'point_coords': [[206.25, 475.0]],
#   'stability_score': 0.9782693386077881,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 66758,
#   'bbox': [521, 295, 240, 609],
#   'predicted_iou': 0.9499987363815308,
#   'point_coords': [[581.25, 575.0]],
#   'stability_score': 0.9594100117683411,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 46386,
#   'bbox': [772, 595, 282, 327],
#   'predicted_iou': 0.9499762058258057,
#   'point_coords': [[881.25, 825.0]],
#   'stability_score': 0.9535073637962341,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1790,
#   'bbox': [632, 1508, 52, 46],
#   'predicted_iou': 0.9483648538589478,
#   'point_coords': [[656.25, 1525.0]],
#   'stability_score': 0.9784768223762512,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 59393,
#   'bbox': [7, 667, 765, 303],
#   'predicted_iou': 0.9460961222648621,
#   'point_coords': [[431.25, 825.0]],
#   'stability_score': 0.9543939828872681,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2918,
#   'bbox': [1001, 1128, 36, 167],
#   'predicted_iou': 0.9432942271232605,
#   'point_coords': [[1031.25, 1225.0]],
#   'stability_score': 0.9706279635429382,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 10209,
#   'bbox': [777, 596, 193, 315],
#   'predicted_iou': 0.9416598081588745,
#   'point_coords': [[843.75, 625.0]],
#   'stability_score': 0.9705712199211121,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8076,
#   'bbox': [121, 1425, 159, 135],
#   'predicted_iou': 0.9407145977020264,
#   'point_coords': [[206.25, 1475.0]],
#   'stability_score': 0.9755560755729675,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 24370,
#   'bbox': [0, 1067, 133, 254],
#   'predicted_iou': 0.9406470656394958,
#   'point_coords': [[56.25, 1175.0]],
#   'stability_score': 0.9567851424217224,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 353,
#   'bbox': [1136, 917, 33, 12],
#   'predicted_iou': 0.9400838613510132,
#   'point_coords': [[1143.75, 925.0]],
#   'stability_score': 0.983098566532135,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 705,
#   'bbox': [990, 571, 63, 15],
#   'predicted_iou': 0.9362611174583435,
#   'point_coords': [[1031.25, 575.0]],
#   'stability_score': 0.9707520604133606,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1142,
#   'bbox': [856, 748, 70, 27],
#   'predicted_iou': 0.9339652061462402,
#   'point_coords': [[918.75, 775.0]],
#   'stability_score': 0.9589743614196777,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 12093,
#   'bbox': [1030, 1107, 167, 106],
#   'predicted_iou': 0.9318860173225403,
#   'point_coords': [[1181.25, 1175.0]],
#   'stability_score': 0.9667695760726929,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3797,
#   'bbox': [556, 468, 139, 88],
#   'predicted_iou': 0.9318810105323792,
#   'point_coords': [[618.75, 475.0]],
#   'stability_score': 0.9586224555969238,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3660,
#   'bbox': [771, 785, 52, 97],
#   'predicted_iou': 0.9314059019088745,
#   'point_coords': [[806.25, 825.0]],
#   'stability_score': 0.979492723941803,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 911,
#   'bbox': [1026, 1552, 45, 27],
#   'predicted_iou': 0.9304625988006592,
#   'point_coords': [[1068.75, 1575.0]],
#   'stability_score': 0.9676026105880737,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2611,
#   'bbox': [918, 1278, 57, 135],
#   'predicted_iou': 0.9301712512969971,
#   'point_coords': [[956.25, 1325.0]],
#   'stability_score': 0.9638826251029968,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 617,
#   'bbox': [834, 1449, 32, 29],
#   'predicted_iou': 0.9300820231437683,
#   'point_coords': [[843.75, 1475.0]],
#   'stability_score': 0.9620253443717957,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4704,
#   'bbox': [658, 1152, 61, 121],
#   'predicted_iou': 0.929856538772583,
#   'point_coords': [[693.75, 1225.0]],
#   'stability_score': 0.9764409065246582,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1000,
#   'bbox': [627, 719, 57, 40],
#   'predicted_iou': 0.9294015765190125,
#   'point_coords': [[656.25, 725.0]],
#   'stability_score': 0.9616895914077759,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1848,
#   'bbox': [940, 1277, 35, 104],
#   'predicted_iou': 0.920843780040741,
#   'point_coords': [[956.25, 1325.0]],
#   'stability_score': 0.9612115025520325,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4418,
#   'bbox': [763, 625, 282, 40],
#   'predicted_iou': 0.9194788336753845,
#   'point_coords': [[918.75, 625.0]],
#   'stability_score': 0.9563096165657043,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 8919,
#   'bbox': [0, 636, 520, 50],
#   'predicted_iou': 0.9112920761108398,
#   'point_coords': [[281.25, 675.0]],
#   'stability_score': 0.9613399505615234,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 6358,
#   'bbox': [509, 1266, 208, 89],
#   'predicted_iou': 0.9097613096237183,
#   'point_coords': [[693.75, 1325.0]],
#   'stability_score': 0.9642248749732971,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2588,
#   'bbox': [777, 723, 63, 71],
#   'predicted_iou': 0.9086828827857971,
#   'point_coords': [[806.25, 775.0]],
#   'stability_score': 0.9705432057380676,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 4241,
#   'bbox': [847, 962, 82, 124],
#   'predicted_iou': 0.9070504903793335,
#   'point_coords': [[881.25, 1025.0]],
#   'stability_score': 0.9515721797943115,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1088,
#   'bbox': [184, 694, 62, 46],
#   'predicted_iou': 0.9064933657646179,
#   'point_coords': [[206.25, 725.0]],
#   'stability_score': 0.9595323801040649,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1916,
#   'bbox': [62, 594, 98, 174],
#   'predicted_iou': 0.9024967551231384,
#   'point_coords': [[93.75, 675.0]],
#   'stability_score': 0.9536659717559814,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1620,
#   'bbox': [347, 1422, 52, 39],
#   'predicted_iou': 0.9019269347190857,
#   'point_coords': [[356.25, 1425.0]],
#   'stability_score': 0.9600242376327515,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1889,
#   'bbox': [935, 1515, 56, 49],
#   'predicted_iou': 0.9008553624153137,
#   'point_coords': [[956.25, 1525.0]],
#   'stability_score': 0.9541473388671875,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 24841,
#   'bbox': [118, 1104, 111, 330],
#   'predicted_iou': 0.8995260000228882,
#   'point_coords': [[206.25, 1175.0]],
#   'stability_score': 0.9608029127120972,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 24954,
#   'bbox': [118, 1027, 135, 407],
#   'predicted_iou': 0.8980826735496521,
#   'point_coords': [[168.75, 1175.0]],
#   'stability_score': 0.9639763832092285,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 12612,
#   'bbox': [119, 1355, 161, 204],
#   'predicted_iou': 0.8945303559303284,
#   'point_coords': [[131.25, 1375.0]],
#   'stability_score': 0.9665523171424866,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 12692,
#   'bbox': [26, 970, 254, 590],
#   'predicted_iou': 0.8905929327011108,
#   'point_coords': [[206.25, 1475.0]],
#   'stability_score': 0.9652955532073975,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 60,
#   'bbox': [351, 1327, 7, 7],
#   'predicted_iou': 0.886478066444397,
#   'point_coords': [[356.25, 1325.0]],
#   'stability_score': 0.9833333492279053,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 5251,
#   'bbox': [253, 833, 58, 129],
#   'predicted_iou': 0.8821089863777161,
#   'point_coords': [[281.25, 875.0]],
#   'stability_score': 0.9644660353660583,
#   'crop_box': [0, 0, 1200, 1600]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1585,
#   'bbox': [0, 1180, 42, 147],
#   'predicted_iou': 0.880347490310669,
#   'point_coords': [[18.75, 1275.0]],
#   'stability_score': 0.9707165360450745,
#   'crop_box': [0, 0, 1200, 1600]}]
